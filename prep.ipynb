# %%
import pandas as pd

# %%
comptages = (
    pd
    .read_csv('/home/tk/Downloads/comptage-velo-donnees-compteurs.csv', sep=';')
    [[
        "Identifiant du compteur",
        "Identifiant du site de comptage",
        "Date et heure de comptage",
        "Comptage horaire",
    ]]
)

comptages
# Out:
#        Identifiant du compteur  Identifiant du site de comptage  \
# 0          100003096-353242251                        100003096
# 1          100003096-353242251                        100003096
# 2          100003096-353242251                        100003096
# 3          100003096-353242251                        100003096
# 4          100003096-353242251                        100003096
# ...                        ...                              ...
# 920975     300030271-353356061                        300030271
# 920976     300030271-353356061                        300030271
# 920977     300030271-353356061                        300030271
# 920978     300030271-353356061                        300030271
# 920979     300030271-353356061                        300030271
#
#         Date et heure de comptage  Comptage horaire
# 0       2022-06-01T06:00:00+02:00              27.0
# 1       2022-06-01T09:00:00+02:00             199.0
# 2       2022-06-01T05:00:00+02:00               7.0
# 3       2022-06-01T07:00:00+02:00              76.0
# 4       2022-06-01T19:00:00+02:00             144.0
# ...                           ...               ...
# 920975  2023-07-23T06:00:00+02:00               2.0
# 920976  2023-07-23T07:00:00+02:00               5.0
# 920977  2023-07-23T11:00:00+02:00              42.0
# 920978  2023-07-23T17:00:00+02:00              15.0
# 920979  2023-07-23T18:00:00+02:00              23.0
#
# [920980 rows x 4 columns]

# %%
comptages.to_csv('datasets/comptages.csv', index=False)

# %%
compteurs = (
    pd
    .read_csv('/home/tk/Downloads/comptage-velo-donnees-compteurs.csv', sep=';')
    .groupby('Identifiant du compteur')
    .first()
    #.reset_index()
    [[
        "Nom du compteur",
        "Identifiant du site de comptage",
        "Nom du site de comptage",
        "Coordonnées géographiques"
    ]]
)

compteurs
# Out:
#                                                            Nom du compteur  \
# Identifiant du compteur
# 100003096-353242251                      97 avenue Denfert Rochereau SO-NE
# 100003097-101003097                                 105 rue La Fayette E-O
# 100003098-101003098                     106 avenue Denfert Rochereau NE-SO
# 100003099-353242239                                 100 rue La Fayette O-E
# 100006300-101006300                             135 avenue Daumesnil SE-NO
# ...                                                                    ...
# 300030219-353355787                               81 boulevard Mortier S-N
# 300030250-353355931                         98 boulevard Poniatowski SO-NE
# 300030250-353355932                         98 boulevard Poniatowski NE-SO
# 300030271-353356061      Face au 49 boulevard du Général Martial Valin ...
# 300030279-353356112            51 boulevard du Général Martial Valin SE-NO
#
#                          Identifiant du site de comptage  \
# Identifiant du compteur
# 100003096-353242251                            100003096
# 100003097-101003097                            100003097
# 100003098-101003098                            100003098
# 100003099-353242239                            100003099
# 100006300-101006300                            100006300
# ...                                                  ...
# 300030219-353355787                            300030219
# 300030250-353355931                            300030250
# 300030250-353355932                            300030250
# 300030271-353356061                            300030271
# 300030279-353356112                            300030279
#
#                                                Nom du site de comptage  \
# Identifiant du compteur
# 100003096-353242251                        97 avenue Denfert Rochereau
# 100003097-101003097                                 105 rue La Fayette
# 100003098-101003098                       106 avenue Denfert Rochereau
# 100003099-353242239                                 100 rue La Fayette
# 100006300-101006300                               135 avenue Daumesnil
# ...                                                                ...
# 300030219-353355787                               81 boulevard Mortier
# 300030250-353355931                           98 boulevard Poniatowski
# 300030250-353355932                           98 boulevard Poniatowski
# 300030271-353356061      Face au 49 boulevard du Général Martial Valin
# 300030279-353356112              51 boulevard du Général Martial Valin
#
#                         Coordonnées géographiques
# Identifiant du compteur
# 100003096-353242251             48.83504, 2.33314
# 100003097-101003097              48.87773, 2.3506
# 100003098-101003098             48.83505, 2.33333
# 100003099-353242239              48.87813, 2.3497
# 100006300-101006300           48.843435, 2.383378
# ...                                           ...
# 300030219-353355787            48.86922, 2.408714
# 300030250-353355931           48.834624, 2.405283
# 300030250-353355932           48.834624, 2.405283
# 300030271-353356061           48.837055, 2.274019
# 300030279-353356112           48.837006, 2.274824
#
# [108 rows x 4 columns]

# %%
compteurs.to_csv('datasets/compteurs.csv')
